# %% [markdown]
# # Bankruptcy Prediction

# %% [raw]
# Predict whether a company or a legal person will become bankrupt in future or not?
#
# When a business or legal person fails to pay the debts of creditors and becomes insolvent at some point, this type of situation is called bankruptcy

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# %%
# import the data set
df=pd.read_csv('bank.csv')
df
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 6819 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  6819 non-null   float64
#  2    ROA(A) before interest and % after tax                   6819 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        6819 non-null   float64
#  4    Operating Gross Margin                                   6819 non-null   float64
#  5    Realized Sales Gross Margin                              6819 non-null   float64
#  6    Operating Profit Rate                                    6819 non-null   float64
#  7    Pre-tax net Interest Rate                                6819 non-null   float64
# ...

# %%
df.describe()
# Out:
#          Bankrupt?   ROA(C) before interest and depreciation before interest  \
# count  6819.000000                                        6819.000000
# mean      0.032263                                           0.505180
# std       0.176710                                           0.060686
# min       0.000000                                           0.000000
# 25%       0.000000                                           0.476527
# 50%       0.000000                                           0.502706
# 75%       0.000000                                           0.535563
# max       1.000000                                           1.000000
#
#         ROA(A) before interest and % after tax  \
# count                              6819.000000
# mean                                  0.558625
# std                                   0.065620
# min                                   0.000000
# 25%                                   0.535543
# ...

# %%
print(df.columns)
# Out:
# Index(['Bankrupt?', ' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Operating Gross Margin', ' Realized Sales Gross Margin',
#        ' Operating Profit Rate', ' Pre-tax net Interest Rate',
#        ' After-tax net Interest Rate',
#        ' Non-industry income and expenditure/revenue',
#        ' Continuous interest rate (after tax)', ' Operating Expense Rate',
#        ' Research and development expense rate', ' Cash flow rate',
#        ' Interest-bearing debt interest rate', ' Tax rate (A)',
#        ' Net Value Per Share (B)', ' Net Value Per Share (A)',
#        ' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons',
#        ' Cash Flow Per Share', ' Revenue Per Share (Yuan ¥)',
#        ' Operating Profit Per Share (Yuan ¥)',
#        ' Per Share Net profit before tax (Yuan ¥)',
# ...

# %% [markdown]
# ## check is there any null value or missing value in our data sets

# %%
df.isnull()
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0         False                                              False
# 1         False                                              False
# 2         False                                              False
# 3         False                                              False
# 4         False                                              False
# ...         ...                                                ...
# 6814      False                                              False
# 6815      False                                              False
# 6816      False                                              False
# 6817      False                                              False
# 6818      False                                              False
#
#        ROA(A) before interest and % after tax  \
# 0                                       False
# 1                                       False
# ...

# %%
df.isnull().sum()
# Out:
# Bankrupt?                                                   0
#  ROA(C) before interest and depreciation before interest    0
#  ROA(A) before interest and % after tax                     0
#  ROA(B) before interest and depreciation after tax          0
#  Operating Gross Margin                                     0
#                                                            ..
#  Liability to Equity                                        0
#  Degree of Financial Leverage (DFL)                         0
#  Interest Coverage Ratio (Interest expense to EBIT)         0
#  Net Income Flag                                            0
#  Equity to Liability                                        0
# Length: 96, dtype: int64

# %%
# The dataset contains 96 columns , look at the correlation before train the model

# %%
sns.set()
sns.heatmap(df.corr())
plt.show()

# %% [markdown]
# #### as the Bankrupt? column is target variable so drop from training sets

# %% [markdown]
# ## Feature selection

# %%
X=df.drop('Bankrupt?',axis=1)
y=df['Bankrupt?']

# %%
X.head()
# Out:
#     ROA(C) before interest and depreciation before interest  \
# 0                                           0.370594
# 1                                           0.464291
# 2                                           0.426071
# 3                                           0.399844
# 4                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# 4                                           0.522298
#
# ...

# %% [markdown]
# ## Now split the data into training and testing set

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=20)

# %% [markdown]
# ## Train the model

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression(max_iter=200)

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=200)

# %%
print(model.score(X_test,y_test))
# Out:
# 0.966275659824047

# %% [markdown]
# # conclusion : So the model is performing well on the training data by giving an accuracy of about 96%
